# %% [markdown]
# # Ноутбук с тестированиями моделей, подбором гиперпараметров и версионированием в ML Flow

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, f1_score, accuracy_score, recall_score, precision_score, precision_recall_curve, confusion_matrix
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from hyperopt import fmin, tpe, hp, Trials, STATUS_OK
import xgboost as xgb
from catboost import CatBoostClassifier

# %%
import mlflow

# %%
min_max_scaler = MinMaxScaler()
standart_scaler = StandardScaler()

# %% [markdown]
# ## Импорт датасета и его преобразование

# %%
df = pd.read_csv("data_win_prediction.csv",sep=";")

# %% [raw]
# Изнально float значения записаны неправильно - через запятую, а не через точку. Надо это исправить:

# %%
df.Team_A_avg_win_percentage = df.Team_A_avg_win_percentage.str.replace(",",".").astype(float)
df.Team_B_avg_win_percentage = df.Team_B_avg_win_percentage.str.replace(",",".").astype(float)
df.Team_A_avg_KR = df.Team_A_avg_KR.str.replace(",",".").astype(float)
df.Team_A_avg_elo = df.Team_A_avg_elo.str.replace(",",".").astype(float)
df.Team_B_avg_KR = df.Team_B_avg_KR.str.replace(",",".").astype(float)

# %%
df.shape
# Out:
# (1465, 9)

# %% [raw]
# Убираем объекты, в которые имеют некоторые карты, т.к в реальных рейтинговых матчах они не попадаются. В целом, эти объекты можно считать как шум:

# %%
values_to_remove = ['aim_map', 'awp_india', 'aim_crashz_dust_1on1', 'de_ravine', 'de_foroglio', 'awp_orange', 'awp_lego_2', 'aim_redline','dorf']
df = df[~df['map'].isin(values_to_remove)]

# %% [raw]
# Убираем колонку с картой, т.к она, на мой взгляд, почти не будет решать в обучении модели:

# %%
df = df.drop(columns=["map","\tMatch ID"])

# %%
df.head()
# Out:
#       win  Team_A_avg_win_percentage  Team_A_avg_KR  Team_A_avg_elo  \
# 0  team a                  58.864865       0.726308          1720.4
# 1  team a                  52.341629       0.764807          1989.6
# 2  team b                  20.202020       0.773030           753.8
# 3  team b                  48.414652       0.733409          2565.0
# 4  team b                  43.571196       0.709982          1484.4
#
#    Team_B_avg_win_percentage  Team_B_avg_KR  Team_B_avg_elo
# 0                  47.289216       0.792615            1536
# 1                  54.823232       0.762641            2073
# 2                  66.095238       0.722705             158
# 3                  62.631108       0.838246            2219
# 4                  55.513072       0.768946            1352

# %%
df.shape
# Out:
# (1452, 7)

# %%
df.win = df.win.map({"team a":0, "team b":1})

# %% [markdown]
# ## Разбиваем датасет на признаки и метки классов

# %%
X, y = df.drop(columns=["win"]), df.win

# %%
columns = X.columns.to_list()

# %% [markdown]
# ## Разделение данных обучающую и тестовую выборку

# %% [raw]
# Проведем эксперимент: какая будет разница при использовании MinMaxScaler / StandartScaler на данных и какая разница, если ничего из этого не использовать?

# %% [markdown]
# ### Без MinMaxScaler и без StandartScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### С MinMaxScaler-ом

# %%
X_mms_scaled = min_max_scaler.fit_transform(X)

# %%
X_mms_train, X_mms_test, y_mms_train, y_mms_test = train_test_split(
    pd.DataFrame(X_mms_scaled, columns=columns), y, test_size=0.33, random_state=42)

# %% [markdown]
# ### С StandartScaler-ом

# %%
X_standart_scaled = standart_scaler.fit_transform(X)

# %%
X_ss_train, X_ss_test, y_ss_train, y_ss_test = train_test_split(
    pd.DataFrame(X_standart_scaled, columns=columns), y, test_size=0.33, random_state=42)

# %% [markdown]
# ### Что лучше?

# %% [raw]
# Проверка скейлеров будет происходить на обучении логистической регрессии!

# %%
for method in ["None", "Standart", "MinMax"]:
    model = LogisticRegression(max_iter=1000, random_state=42)
    f1 = 0.0
    if method == "None":
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        f1 = f1_score(y_test, y_pred)
    elif method == "Standart":
        model.fit(X_ss_train, y_ss_train)
        y_pred = model.predict(X_ss_test)
        f1 = f1_score(y_ss_test, y_pred)
    elif method == "MinMax":
        model.fit(X_mms_train, y_mms_train)
        y_pred = model.predict(X_mms_test)
        f1 = f1_score(y_mms_test, y_pred)
    print(f1)
# Out:
# 0.8052930056710775
# 0.8052930056710775
# 0.799249530956848

# %% [markdown]
# Видим, что лучше использовать StandartScaler, либо вообще не преобразовывать данные. Но лучше все же использовать StandartScaler, что я в дальнейшем и буду делать.

# %% [markdown]
# ## Обучение моделей и выбор лучших

# %% [markdown]
# Настало время обучения. Проверять буду следующие модели: "мою эврестическую модель", логистическую регрессию, XGBoost и простую нейросеть.

# %% [markdown]
# Для всех моделей я буду искать гипер-параметры. Их можно искать различными способами: GridSearch, RandomSearch, Optuna, Hyperopt (Я простирую их все).

# %% [markdown]
# ### Эврестическая модель

# %% [markdown]
# Данные имеют следующий вид:

# %%
df.head(3)
# Out:
#    win  Team_A_avg_win_percentage  Team_A_avg_KR  Team_A_avg_elo  \
# 0    0                  58.864865       0.726308          1720.4
# 1    0                  52.341629       0.764807          1989.6
# 2    1                  20.202020       0.773030           753.8
#
#    Team_B_avg_win_percentage  Team_B_avg_KR  Team_B_avg_elo
# 0                  47.289216       0.792615            1536
# 1                  54.823232       0.762641            2073
# 2                  66.095238       0.722705             158

# %% [markdown]
# Зачем обучать модель, если можно взглянуть на данные и выявить победителя из тех, у кого больше среднее эло и больше кд? Зачем здесь ML?

# %% [raw]
# Идея модели:
# Для того, чтобы сказать, что команда А победит, нам достаточно удовлетворения двух из трех следующих условий:
# 1. Team_A_avg_win_percentage > Team_B_avg_win_percentage
# 2. Team_A_avg_KR > Team_B_avg_KR
# 3. Team_A_avg_elo > Team_B_avg_elo

# %% [raw]
# Создаем модель:

# %%
class HeuristicsModel:
    def __init__(self, coincidence: int = 2) -> None:
        """
        Эвристическая модель
        coincidence - это количество совпадений из следующих условий:
            1. Team_A_avg_win_percentage > Team_B_avg_win_percentage
            2. Team_A_avg_KR > Team_B_avg_KR
            3. Team_A_avg_elo > Team_B_avg_elo
        """
        if coincidence in [0, 1, 2, 3]:
            self.coincidence = coincidence
        else:
            raise InvalidParameterError("coincidence должен быть в диапазоне [0, 3] - от нуля до трех включительно!")

    def predict(self, data: np.ndarray | pd.DataFrame) -> np.ndarray:
        pred = np.empty(data.shape[0])
        index = 0
        df = data.copy()
        if isinstance(data, pd.DataFrame):
            df = data.to_numpy()
        for object_ in df:
            data_coincidence = 0
            if object_[0] > object_[3]:
                data_coincidence += 1
            if object_[1] > object_[4]:
                data_coincidence += 1
            if object_[2] > object_[5]:
                data_coincidence += 1
            if data_coincidence >= self.coincidence:
                pred[index] = 1
            else:
                pred[index] = 0
            index += 1
        return pred

# %%
for c in [0, 1, 2, 3]:
    hm = HeuristicsModel(coincidence=c)
    hm_pred = hm.predict(X_ss_test)
    f1_hm_pred = f1_score(y_ss_test, hm_pred)
    print(f"f1 для coincidence равной {c}: ",f1_hm_pred)
# Out:
# f1 для coincidence равной 0:  0.6938775510204082
# f1 для coincidence равной 1:  0.5522620904836193
# f1 для coincidence равной 2:  0.30353430353430355
# f1 для coincidence равной 3:  0.0729483282674772

# %% [raw]
# Мы видим что при любых показателях coincidence (совпадения) наша модель плохо отрабатывает. Значит здесь не достаточно посмотреть на статистику команд и сказать какая из них победит, здесь есть какие-то другие закономерности, которые просто так (без ml) не увидишь. ML здесь будет как раз кстати!
# И что интересно, сейчас эта модель лучше отрабатывает, когда coincidence = 0, это значит, что f1 был бы равен 0.69, если бы мы всегда говорили, что команда А проиграет.

# %% [markdown]
# ### Логистическая регрессия

# %% [markdown]
# LogisticRegression - одна из простых и хороших моделей.

# %%
logistic_regression = LogisticRegression(
    solver='lbfgs',
    tol=1e-6,
    max_iter=1000
)

# %%
log_regression_param_grid = {
    'penalty': ['l1', 'l2'],
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'solver': ['liblinear', 'saga'],
    'class_weight': [None, 'balanced']
}

# %% [markdown]
# #### GridSearchCV

# %%
grid_search_log_regression = GridSearchCV(
    estimator=logistic_regression, 
    param_grid=log_regression_param_grid,
    scoring="f1",
    cv=3,
    n_jobs=-1,
    verbose=1
)

# %%
grid_search_log_regression.fit(X_ss_train, y_ss_train)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# GridSearchCV(cv=3, estimator=LogisticRegression(max_iter=1000, tol=1e-06),
#              n_jobs=-1,
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                          'class_weight': [None, 'balanced'],
#                          'penalty': ['l1', 'l2'],
#                          'solver': ['liblinear', 'saga']},
#              scoring='f1', verbose=1)

# %%
grid_search_params = grid_search_log_regression.best_params_
print(grid_search_params)
print(grid_search_log_regression.best_score_)
# Out:
# {'C': 0.1, 'class_weight': None, 'penalty': 'l1', 'solver': 'saga'}
# 0.8106130502121037

# %% [markdown]
# #### RandomizedSearchCV

# %%
randomized_searcg_log_regression = RandomizedSearchCV(
    estimator=logistic_regression, 
    param_distributions=log_regression_param_grid,
    scoring="f1",
    cv=3,
    n_jobs=-1,
    verbose=1
)

# %%
randomized_searcg_log_regression.fit(X_ss_train, y_ss_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3, estimator=LogisticRegression(max_iter=1000, tol=1e-06),
#                    n_jobs=-1,
#                    param_distributions={'C': [0.001, 0.01, 0.1, 1, 10, 100],
#                                         'class_weight': [None, 'balanced'],
#                                         'penalty': ['l1', 'l2'],
#                                         'solver': ['liblinear', 'saga']},
#                    scoring='f1', verbose=1)

# %%
randomized_search_params = randomized_searcg_log_regression.best_params_
print(randomized_search_params)
print(randomized_searcg_log_regression.best_score_)
# Out:
# {'solver': 'saga', 'penalty': 'l1', 'class_weight': None, 'C': 0.1}
# 0.8106130502121037

# %% [markdown]
# #### Hyperopt

# %%
space = {
    'C': hp.loguniform('C', np.log(0.001), np.log(100)),
    'penalty': hp.choice('penalty', ['l1', 'l2']),
    'solver': hp.choice('solver', ['liblinear', 'saga']),
    'class_weight': hp.choice('class_weight', [None, 'balanced']),
}

# %%
def objective(params):
    try:
        model = LogisticRegression(
            C=params['C'],
            penalty=params['penalty'],
            solver=params['solver'],
            class_weight=params['class_weight'],
            random_state=42,
            max_iter=3000
        )
        
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        f1 = f1_score(y_test, y_pred)
        
        return {'loss': -f1, 'status': STATUS_OK}
        
    except Exception as e:
        print(f"Error: {e}")
        return {'loss': 1.0, 'status': STATUS_OK}

# %%
trials = Trials()
best = fmin(
    fn=objective,
    space=space,
    algo=tpe.suggest,
    max_evals=100,
    trials=trials
)
# Out:
# 100%|█████████████████████████████████████████████| 100/100 [00:10<00:00,  9.78trial/s, best loss: -0.8127340823970037]

# %%
best
# Out:
# {'C': 0.0027740713874680476, 'class_weight': 0, 'penalty': 0, 'solver': 0}

# %% [raw]
# Лучшие параметры для hyperopt: {'C': 0.00300879125633124, 'class_weight': None, 'penalty': 'l1', 'solver': 'saga'}

# %%
hyperopt_params = {'C': 0.01, 'class_weight': 'balanced', 'penalty': 'l1', 'solver': 'saga'}

# %% [raw]
# Запоминаем best score - 0.81273408

# %% [markdown]
# #### Optuna

# %%
import optuna

def objective_optuna(trial):
    params = {
        'C': trial.suggest_float('C', 0.001, 100, log=True),
        'penalty': trial.suggest_categorical('penalty', ['l1', 'l2']),
        'solver': trial.suggest_categorical('solver', ['liblinear', 'saga']),
        'class_weight': trial.suggest_categorical("class_weight", [None, 'balanced']),
        'max_iter': 1000,
        'random_state': 42
    }
    
    model = LogisticRegression(**params)
    model.fit(X_ss_train, y_ss_train)
    
    y_pred = model.predict(X_ss_test)
    f1 = f1_score(y_ss_test, y_pred)
    
    return f1

study = optuna.create_study(direction='maximize')
study.optimize(objective_optuna, n_trials=50, show_progress_bar=True)

print("Best parameters:", study.best_params)
print("Best F1-score:", study.best_value)
# Out:
# [I 2025-11-03 19:19:59,595] A new study created in memory with name: no-name-3312fd21-7a75-42e6-9707-01dbe2614d9f
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-03 19:19:59,636] Trial 0 finished with value: 0.7928994082840237 and parameters: {'C': 0.21605123311770782, 'penalty': 'l1', 'solver': 'liblinear', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.7928994082840237.
# [I 2025-11-03 19:19:59,655] Trial 1 finished with value: 0.7913385826771654 and parameters: {'C': 11.76980824772972, 'penalty': 'l2', 'solver': 'saga', 'class_weight': 'balanced'}. Best is trial 0 with value: 0.7928994082840237.
# [I 2025-11-03 19:19:59,676] Trial 2 finished with value: 0.79296875 and parameters: {'C': 0.009374575013063567, 'penalty': 'l1', 'solver': 'saga', 'class_weight': 'balanced'}. Best is trial 2 with value: 0.79296875.
# [I 2025-11-03 19:19:59,699] Trial 3 finished with value: 0.7913385826771654 and parameters: {'C': 48.70609946389046, 'penalty': 'l1', 'solver': 'liblinear', 'class_weight': 'balanced'}. Best is trial 2 with value: 0.79296875.
# [I 2025-11-03 19:19:59,728] Trial 4 finished with value: 0.7913385826771654 and parameters: {'C': 46.03169430602872, 'penalty': 'l1', 'solver': 'liblinear', 'class_weight': 'balanced'}. Best is trial 2 with value: 0.79296875.
# [I 2025-11-03 19:19:59,743] Trial 5 finished with value: 0.7913385826771654 and parameters: {'C': 2.923612735617646, 'penalty': 'l1', 'solver': 'saga', 'class_weight': 'balanced'}. Best is trial 2 with value: 0.79296875.
# [I 2025-11-03 19:19:59,763] Trial 6 finished with value: 0.793713163064833 and parameters: {'C': 0.40484776892295465, 'penalty': 'l1', 'solver': 'saga', 'class_weight': 'balanced'}. Best is trial 6 with value: 0.793713163064833.
# [I 2025-11-03 19:19:59,781] Trial 7 finished with value: 0.8082706766917294 and parameters: {'C': 0.0254129509058059, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 7 with value: 0.8082706766917294.
# [I 2025-11-03 19:19:59,799] Trial 8 finished with value: 0.8052930056710775 and parameters: {'C': 0.48447202288987723, 'penalty': 'l1', 'solver': 'liblinear', 'class_weight': None}. Best is trial 7 with value: 0.8082706766917294.
# [I 2025-11-03 19:19:59,813] Trial 9 finished with value: 0.8068181818181818 and parameters: {'C': 0.06326454988771318, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 7 with value: 0.8082706766917294.
# [I 2025-11-03 19:19:59,840] Trial 10 finished with value: 0.8062283737024222 and parameters: {'C': 0.0015250192247741874, 'penalty': 'l2', 'solver': 'saga', 'class_weight': None}. Best is trial 7 with value: 0.8082706766917294.
# [I 2025-11-03 19:19:59,859] Trial 11 finished with value: 0.8037735849056604 and parameters: {'C': 0.028078614249386583, 'penalty': 'l2', 'solver': 'saga', 'class_weight': None}. Best is trial 7 with value: 0.8082706766917294.
# [I 2025-11-03 19:19:59,880] Trial 12 finished with value: 0.8082706766917294 and parameters: {'C': 0.028211563818061156, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 7 with value: 0.8082706766917294.
# [I 2025-11-03 19:19:59,901] Trial 13 finished with value: 0.7718223583460949 and parameters: {'C': 0.005170342542974214, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 7 with value: 0.8082706766917294.
# [I 2025-11-03 19:19:59,920] Trial 14 finished with value: 0.8037735849056604 and parameters: {'C': 0.05207316278002108, 'penalty': 'l2', 'solver': 'saga', 'class_weight': None}. Best is trial 7 with value: 0.8082706766917294.
# [I 2025-11-03 19:19:59,945] Trial 15 finished with value: 0.6938775510204082 and parameters: {'C': 0.0019056904234944153, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 7 with value: 0.8082706766917294.
# [I 2025-11-03 19:19:59,966] Trial 16 finished with value: 0.8118081180811808 and parameters: {'C': 0.010445219483756586, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 16 with value: 0.8118081180811808.
# [I 2025-11-03 19:19:59,991] Trial 17 finished with value: 0.81 and parameters: {'C': 0.006063677562263849, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 16 with value: 0.8118081180811808.
# [I 2025-11-03 19:20:00,013] Trial 18 finished with value: 0.7877629063097514 and parameters: {'C': 0.006077697799250771, 'penalty': 'l2', 'solver': 'liblinear', 'class_weight': None}. Best is trial 16 with value: 0.8118081180811808.
# [I 2025-11-03 19:20:00,041] Trial 19 finished with value: 0.8075471698113208 and parameters: {'C': 0.16922730570630864, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 16 with value: 0.8118081180811808.
# [I 2025-11-03 19:20:00,066] Trial 20 finished with value: 0.6938775510204082 and parameters: {'C': 0.0010214092337291279, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 16 with value: 0.8118081180811808.
# [I 2025-11-03 19:20:00,085] Trial 21 finished with value: 0.8148148148148148 and parameters: {'C': 0.015234392761944196, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,109] Trial 22 finished with value: 0.8138686131386861 and parameters: {'C': 0.009155223532821662, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,130] Trial 23 finished with value: 0.8148148148148148 and parameters: {'C': 0.013427669631175471, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,154] Trial 24 finished with value: 0.8135593220338984 and parameters: {'C': 0.08305182875787445, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,193] Trial 25 finished with value: 0.8037735849056604 and parameters: {'C': 1.0076720985450185, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,213] Trial 26 finished with value: 0.7938931297709924 and parameters: {'C': 0.0032183792083830317, 'penalty': 'l2', 'solver': 'liblinear', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,233] Trial 27 finished with value: 0.8104089219330854 and parameters: {'C': 0.016921676857054747, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,259] Trial 28 finished with value: 0.8135593220338984 and parameters: {'C': 0.12625815828172543, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,277] Trial 29 finished with value: 0.0 and parameters: {'C': 0.0033499372996959246, 'penalty': 'l1', 'solver': 'liblinear', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,305] Trial 30 finished with value: 0.8097014925373134 and parameters: {'C': 0.01769369366710416, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,323] Trial 31 finished with value: 0.8135593220338984 and parameters: {'C': 0.09772450336816378, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,345] Trial 32 finished with value: 0.8052930056710775 and parameters: {'C': 0.047679800535203896, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,369] Trial 33 finished with value: 0.8037735849056604 and parameters: {'C': 0.2269740410898445, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,391] Trial 34 finished with value: 0.79296875 and parameters: {'C': 0.011918974547269352, 'penalty': 'l1', 'solver': 'saga', 'class_weight': 'balanced'}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,420] Trial 35 finished with value: 0.7913385826771654 and parameters: {'C': 0.7967424182774099, 'penalty': 'l1', 'solver': 'saga', 'class_weight': 'balanced'}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,437] Trial 36 finished with value: 0.803030303030303 and parameters: {'C': 2.9825007343242778, 'penalty': 'l2', 'solver': 'liblinear', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,468] Trial 37 finished with value: 0.7913385826771654 and parameters: {'C': 0.06495363938975579, 'penalty': 'l1', 'solver': 'saga', 'class_weight': 'balanced'}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,494] Trial 38 finished with value: 0.8131868131868132 and parameters: {'C': 0.00963531414954235, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,518] Trial 39 finished with value: 0.79296875 and parameters: {'C': 0.034301350365577146, 'penalty': 'l1', 'solver': 'saga', 'class_weight': 'balanced'}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,544] Trial 40 finished with value: 0.803030303030303 and parameters: {'C': 21.637861613302537, 'penalty': 'l1', 'solver': 'liblinear', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,567] Trial 41 finished with value: 0.8135593220338984 and parameters: {'C': 0.12381564007393678, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,591] Trial 42 finished with value: 0.8135593220338984 and parameters: {'C': 0.09670532397797406, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,616] Trial 43 finished with value: 0.8052930056710775 and parameters: {'C': 0.30204506549416354, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,637] Trial 44 finished with value: 0.6938775510204082 and parameters: {'C': 0.002853551583548349, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,663] Trial 45 finished with value: 0.8097014925373134 and parameters: {'C': 0.018573218171028427, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,689] Trial 46 finished with value: 0.8037735849056604 and parameters: {'C': 0.597973710556609, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,711] Trial 47 finished with value: 0.783625730994152 and parameters: {'C': 0.039124848265887954, 'penalty': 'l2', 'solver': 'saga', 'class_weight': 'balanced'}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,737] Trial 48 finished with value: 0.8052930056710775 and parameters: {'C': 1.8362387783524623, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# [I 2025-11-03 19:20:00,764] Trial 49 finished with value: 0.8135593220338984 and parameters: {'C': 0.07981819674569293, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}. Best is trial 21 with value: 0.8148148148148148.
# Best parameters: {'C': 0.015234392761944196, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}
# Best F1-score: 0.8148148148148148

# %%
optuna_logregr = study.best_params
print(optuna_logregr)
# Out:
# {'C': 0.007294894989290226, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None}

# %% [raw]
# У оптюны чуть лучше score, чем у hyperopt, поэтому вдальнейшем буду использовать только оптюну.
# Оптюна вцелом нашла лучшие параметры по f1, чем в gridsearch, randomizedsearch и hyperopt

# %% [markdown]
# ### Random Forest

# %%
def objective_optuna_rf(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 30),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 15),
        'max_features': trial.suggest_categorical('max_features', ['sqrt', 'log2', None]),
        'max_leaf_nodes': trial.suggest_int('max_leaf_nodes', 10, 1000),
        'min_impurity_decrease': trial.suggest_float('min_impurity_decrease', 0.0, 0.1),
        'bootstrap': trial.suggest_categorical('bootstrap', [True, False]),
        'criterion': trial.suggest_categorical('criterion', ['gini', 'entropy']),
        'random_state': 42
    }
    
    model = RandomForestClassifier(**params)
    model.fit(X_ss_train, y_ss_train)
    
    y_pred = model.predict(X_ss_test)
    f1 = f1_score(y_ss_test, y_pred)
    
    return f1

study_rf = optuna.create_study(direction='maximize')
study_rf.optimize(objective_optuna_rf, n_trials=50, show_progress_bar=True)

print("Best parameters:", study_rf.best_params)
print("Best F1-score:", study_rf.best_value)
# Out:
# [I 2025-11-03 19:24:33,542] A new study created in memory with name: no-name-b8d40074-5c27-47ad-88c1-94cd821b9e96
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-03 19:24:37,183] Trial 0 finished with value: 0.8014705882352942 and parameters: {'n_estimators': 437, 'max_depth': 20, 'min_samples_split': 21, 'min_samples_leaf': 1, 'max_features': None, 'max_leaf_nodes': 668, 'min_impurity_decrease': 0.012968750399185791, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8014705882352942.
# [I 2025-11-03 19:24:38,557] Trial 1 finished with value: 0.7986577181208053 and parameters: {'n_estimators': 555, 'max_depth': 12, 'min_samples_split': 19, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_leaf_nodes': 626, 'min_impurity_decrease': 0.04628860109064634, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8014705882352942.
# [I 2025-11-03 19:24:40,374] Trial 2 finished with value: 0.7934426229508197 and parameters: {'n_estimators': 879, 'max_depth': 20, 'min_samples_split': 23, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 34, 'min_impurity_decrease': 0.056291774338624714, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 0 with value: 0.8014705882352942.
# [I 2025-11-03 19:24:41,658] Trial 3 finished with value: 0.7813620071684588 and parameters: {'n_estimators': 268, 'max_depth': 3, 'min_samples_split': 29, 'min_samples_leaf': 14, 'max_features': None, 'max_leaf_nodes': 594, 'min_impurity_decrease': 0.07310314346011576, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8014705882352942.
# [I 2025-11-03 19:24:43,287] Trial 4 finished with value: 0.7977099236641222 and parameters: {'n_estimators': 702, 'max_depth': 12, 'min_samples_split': 30, 'min_samples_leaf': 13, 'max_features': 'log2', 'max_leaf_nodes': 751, 'min_impurity_decrease': 0.002506437149457497, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 0 with value: 0.8014705882352942.
# [I 2025-11-03 19:24:44,121] Trial 5 finished with value: 0.7950089126559715 and parameters: {'n_estimators': 594, 'max_depth': 9, 'min_samples_split': 15, 'min_samples_leaf': 12, 'max_features': 'log2', 'max_leaf_nodes': 356, 'min_impurity_decrease': 0.016393234346568752, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 0 with value: 0.8014705882352942.
# [I 2025-11-03 19:24:49,155] Trial 6 finished with value: 0.7810650887573964 and parameters: {'n_estimators': 981, 'max_depth': 19, 'min_samples_split': 9, 'min_samples_leaf': 15, 'max_features': None, 'max_leaf_nodes': 661, 'min_impurity_decrease': 0.005395840351253612, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8014705882352942.
# [I 2025-11-03 19:24:50,279] Trial 7 finished with value: 0.7945205479452054 and parameters: {'n_estimators': 658, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_leaf_nodes': 998, 'min_impurity_decrease': 0.06179831315445266, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8014705882352942.
# [I 2025-11-03 19:24:52,695] Trial 8 finished with value: 0.7813620071684588 and parameters: {'n_estimators': 963, 'max_depth': 3, 'min_samples_split': 11, 'min_samples_leaf': 2, 'max_features': None, 'max_leaf_nodes': 41, 'min_impurity_decrease': 0.09425764482916493, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8014705882352942.
# [I 2025-11-03 19:24:53,251] Trial 9 finished with value: 0.7986577181208053 and parameters: {'n_estimators': 375, 'max_depth': 18, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 851, 'min_impurity_decrease': 0.05820160956257384, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8014705882352942.
# [I 2025-11-03 19:24:53,547] Trial 10 finished with value: 0.7768924302788844 and parameters: {'n_estimators': 117, 'max_depth': 14, 'min_samples_split': 24, 'min_samples_leaf': 6, 'max_features': None, 'max_leaf_nodes': 389, 'min_impurity_decrease': 0.03171640823069108, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 0 with value: 0.8014705882352942.
# [I 2025-11-03 19:24:54,211] Trial 11 finished with value: 0.7986577181208053 and parameters: {'n_estimators': 427, 'max_depth': 8, 'min_samples_split': 19, 'min_samples_leaf': 6, 'max_features': 'log2', 'max_leaf_nodes': 466, 'min_impurity_decrease': 0.033482114199325765, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8014705882352942.
# [I 2025-11-03 19:24:56,199] Trial 12 finished with value: 0.7862595419847328 and parameters: {'n_estimators': 473, 'max_depth': 15, 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': None, 'max_leaf_nodes': 267, 'min_impurity_decrease': 0.033498738104131176, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8014705882352942.
# [I 2025-11-03 19:24:57,591] Trial 13 finished with value: 0.8137432188065099 and parameters: {'n_estimators': 778, 'max_depth': 7, 'min_samples_split': 15, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_leaf_nodes': 799, 'min_impurity_decrease': 0.018613527760989956, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 13 with value: 0.8137432188065099.
# [I 2025-11-03 19:24:58,964] Trial 14 finished with value: 0.8130671506352087 and parameters: {'n_estimators': 780, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_leaf_nodes': 817, 'min_impurity_decrease': 0.01754438916678954, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 13 with value: 0.8137432188065099.
# [I 2025-11-03 19:25:00,376] Trial 15 finished with value: 0.804920913884007 and parameters: {'n_estimators': 754, 'max_depth': 6, 'min_samples_split': 14, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'max_leaf_nodes': 910, 'min_impurity_decrease': 0.021811111701341118, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 13 with value: 0.8137432188065099.
# [I 2025-11-03 19:25:01,789] Trial 16 finished with value: 0.804920913884007 and parameters: {'n_estimators': 806, 'max_depth': 6, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_leaf_nodes': 803, 'min_impurity_decrease': 0.025130458362399168, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 13 with value: 0.8137432188065099.
# [I 2025-11-03 19:25:03,057] Trial 17 finished with value: 0.7986577181208053 and parameters: {'n_estimators': 860, 'max_depth': 9, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'max_leaf_nodes': 998, 'min_impurity_decrease': 0.04156511163147436, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 13 with value: 0.8137432188065099.
# [I 2025-11-03 19:25:04,154] Trial 18 finished with value: 0.8134328358208955 and parameters: {'n_estimators': 655, 'max_depth': 6, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_leaf_nodes': 746, 'min_impurity_decrease': 0.011627150733864864, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 13 with value: 0.8137432188065099.
# [I 2025-11-03 19:25:05,454] Trial 19 finished with value: 0.8106060606060606 and parameters: {'n_estimators': 648, 'max_depth': 5, 'min_samples_split': 11, 'min_samples_leaf': 10, 'max_features': 'log2', 'max_leaf_nodes': 513, 'min_impurity_decrease': 0.0010915857507894124, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 13 with value: 0.8137432188065099.
# [I 2025-11-03 19:25:06,269] Trial 20 finished with value: 0.7865961199294532 and parameters: {'n_estimators': 531, 'max_depth': 8, 'min_samples_split': 17, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_leaf_nodes': 746, 'min_impurity_decrease': 0.07559194734571097, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 13 with value: 0.8137432188065099.
# [I 2025-11-03 19:25:07,585] Trial 21 finished with value: 0.8185185185185185 and parameters: {'n_estimators': 769, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_leaf_nodes': 842, 'min_impurity_decrease': 0.011588676266373742, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:09,075] Trial 22 finished with value: 0.8149532710280374 and parameters: {'n_estimators': 880, 'max_depth': 4, 'min_samples_split': 9, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_leaf_nodes': 906, 'min_impurity_decrease': 0.009643232892031256, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:10,527] Trial 23 finished with value: 0.8041958041958042 and parameters: {'n_estimators': 913, 'max_depth': 4, 'min_samples_split': 8, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 909, 'min_impurity_decrease': 0.026292458918229126, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:11,985] Trial 24 finished with value: 0.8090737240075614 and parameters: {'n_estimators': 822, 'max_depth': 10, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_leaf_nodes': 923, 'min_impurity_decrease': 0.00831478845442399, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:13,135] Trial 25 finished with value: 0.7945670628183361 and parameters: {'n_estimators': 751, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 'log2', 'max_leaf_nodes': 883, 'min_impurity_decrease': 0.03952940962205515, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:14,580] Trial 26 finished with value: 0.8100358422939068 and parameters: {'n_estimators': 888, 'max_depth': 7, 'min_samples_split': 17, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 768, 'min_impurity_decrease': 0.021677371019839936, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:15,936] Trial 27 finished with value: 0.8068181818181818 and parameters: {'n_estimators': 720, 'max_depth': 4, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_leaf_nodes': 950, 'min_impurity_decrease': 0.0006343924312923691, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:17,485] Trial 28 finished with value: 0.8178438661710037 and parameters: {'n_estimators': 941, 'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'max_leaf_nodes': 157, 'min_impurity_decrease': 0.010591867127500128, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:19,123] Trial 29 finished with value: 0.8134328358208955 and parameters: {'n_estimators': 991, 'max_depth': 11, 'min_samples_split': 12, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'max_leaf_nodes': 204, 'min_impurity_decrease': 0.011383564764569344, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:20,686] Trial 30 finished with value: 0.8081180811808119 and parameters: {'n_estimators': 929, 'max_depth': 13, 'min_samples_split': 5, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'max_leaf_nodes': 179, 'min_impurity_decrease': 0.014092178868807866, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:22,098] Trial 31 finished with value: 0.8090737240075614 and parameters: {'n_estimators': 827, 'max_depth': 8, 'min_samples_split': 16, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_leaf_nodes': 694, 'min_impurity_decrease': 0.008885607861014303, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:23,616] Trial 32 finished with value: 0.8110091743119267 and parameters: {'n_estimators': 924, 'max_depth': 10, 'min_samples_split': 13, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 598, 'min_impurity_decrease': 0.01685351793141454, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:25,036] Trial 33 finished with value: 0.8 and parameters: {'n_estimators': 866, 'max_depth': 7, 'min_samples_split': 21, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_leaf_nodes': 528, 'min_impurity_decrease': 0.02732275735595512, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:26,479] Trial 34 finished with value: 0.8113207547169812 and parameters: {'n_estimators': 834, 'max_depth': 5, 'min_samples_split': 9, 'min_samples_leaf': 6, 'max_features': 'log2', 'max_leaf_nodes': 833, 'min_impurity_decrease': 0.007946009664618421, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:27,578] Trial 35 finished with value: 0.7945670628183361 and parameters: {'n_estimators': 690, 'max_depth': 3, 'min_samples_split': 16, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'max_leaf_nodes': 108, 'min_impurity_decrease': 0.050117718464808704, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:28,580] Trial 36 finished with value: 0.8092691622103387 and parameters: {'n_estimators': 607, 'max_depth': 5, 'min_samples_split': 25, 'min_samples_leaf': 7, 'max_features': 'log2', 'max_leaf_nodes': 695, 'min_impurity_decrease': 0.0215384009947083, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:30,286] Trial 37 finished with value: 0.8110091743119267 and parameters: {'n_estimators': 998, 'max_depth': 7, 'min_samples_split': 21, 'min_samples_leaf': 12, 'max_features': 'sqrt', 'max_leaf_nodes': 326, 'min_impurity_decrease': 0.005201634521638965, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:31,640] Trial 38 finished with value: 0.8125 and parameters: {'n_estimators': 776, 'max_depth': 10, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_leaf_nodes': 423, 'min_impurity_decrease': 0.015260985793591818, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:34,492] Trial 39 finished with value: 0.7800687285223368 and parameters: {'n_estimators': 945, 'max_depth': 11, 'min_samples_split': 18, 'min_samples_leaf': 12, 'max_features': None, 'max_leaf_nodes': 650, 'min_impurity_decrease': 0.09428858588018163, 'bootstrap': False, 'criterion': 'entropy'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:36,023] Trial 40 finished with value: 0.7945205479452054 and parameters: {'n_estimators': 886, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 556, 'min_impurity_decrease': 0.06765825123325139, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:37,193] Trial 41 finished with value: 0.8134328358208955 and parameters: {'n_estimators': 653, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_leaf_nodes': 733, 'min_impurity_decrease': 0.012542294135684017, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:38,475] Trial 42 finished with value: 0.8127340823970037 and parameters: {'n_estimators': 725, 'max_depth': 3, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_leaf_nodes': 872, 'min_impurity_decrease': 0.004854906752097382, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:39,513] Trial 43 finished with value: 0.8036363636363636 and parameters: {'n_estimators': 587, 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 962, 'min_impurity_decrease': 0.019558430475257547, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:41,636] Trial 44 finished with value: 0.7992351816443595 and parameters: {'n_estimators': 806, 'max_depth': 7, 'min_samples_split': 14, 'min_samples_leaf': 1, 'max_features': None, 'max_leaf_nodes': 835, 'min_impurity_decrease': 0.013214291087082145, 'bootstrap': True, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:42,587] Trial 45 finished with value: 0.7986577181208053 and parameters: {'n_estimators': 685, 'max_depth': 16, 'min_samples_split': 10, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_leaf_nodes': 808, 'min_impurity_decrease': 0.02923613924941107, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:43,460] Trial 46 finished with value: 0.8027681660899654 and parameters: {'n_estimators': 506, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_leaf_nodes': 777, 'min_impurity_decrease': 0.08615977685215644, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:44,429] Trial 47 finished with value: 0.7956600361663653 and parameters: {'n_estimators': 629, 'max_depth': 8, 'min_samples_split': 7, 'min_samples_leaf': 15, 'max_features': 'sqrt', 'max_leaf_nodes': 626, 'min_impurity_decrease': 0.010105130845103906, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:45,707] Trial 48 finished with value: 0.7938342967244701 and parameters: {'n_estimators': 288, 'max_depth': 6, 'min_samples_split': 12, 'min_samples_leaf': 5, 'max_features': None, 'max_leaf_nodes': 717, 'min_impurity_decrease': 0.0043069919478273605, 'bootstrap': True, 'criterion': 'entropy'}. Best is trial 21 with value: 0.8185185185185185.
# [I 2025-11-03 19:25:46,809] Trial 49 finished with value: 0.7986577181208053 and parameters: {'n_estimators': 765, 'max_depth': 12, 'min_samples_split': 10, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_leaf_nodes': 867, 'min_impurity_decrease': 0.03834085270998062, 'bootstrap': False, 'criterion': 'gini'}. Best is trial 21 with value: 0.8185185185185185.
# Best parameters: {'n_estimators': 769, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_leaf_nodes': 842, 'min_impurity_decrease': 0.011588676266373742, 'bootstrap': True, 'criterion': 'gini'}
# Best F1-score: 0.8185185185185185

# %%
optuna_rf = study_rf.best_params
optuna_rf_score = study_rf.best_value
print("Best random forest params: ",optuna_rf)
print("Best random forest f1-score",optuna_rf_score)
# Out:
# Best random forest params:  {'n_estimators': 769, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_leaf_nodes': 842, 'min_impurity_decrease': 0.011588676266373742, 'bootstrap': True, 'criterion': 'gini'}
# Best random forest f1-score 0.8185185185185185

# %% [markdown]
# ### Xgboost

# %%
def objective_optuna_xgboost(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 1),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 1),
        'random_state': 42
    }
    
    model = xgb.XGBClassifier(**params)
    model.fit(X_ss_train, y_ss_train)
    
    y_pred = model.predict(X_ss_test)
    f1 = f1_score(y_ss_test, y_pred)
    
    return f1

study_xgboost = optuna.create_study(direction='maximize')
study_xgboost.optimize(objective_optuna_xgboost, n_trials=50, show_progress_bar=True)

print("Best parameters:", study_xgboost.best_params)
print("Best F1-score:", study_xgboost.best_value)
# Out:
# [I 2025-11-03 19:47:10,972] A new study created in memory with name: no-name-fa3d0f8a-5e6d-4276-acb6-369540dcf844
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-03 19:47:11,752] Trial 0 finished with value: 0.7868217054263565 and parameters: {'n_estimators': 962, 'max_depth': 3, 'learning_rate': 0.20171161152284275, 'subsample': 0.9185157186154527, 'colsample_bytree': 0.910495941029367, 'reg_alpha': 0.9083873758700546, 'reg_lambda': 0.7789507213985059}. Best is trial 0 with value: 0.7868217054263565.
# [I 2025-11-03 19:47:12,133] Trial 1 finished with value: 0.7749510763209393 and parameters: {'n_estimators': 197, 'max_depth': 9, 'learning_rate': 0.037741022582054445, 'subsample': 0.910138858488377, 'colsample_bytree': 0.8512535188117203, 'reg_alpha': 0.5044358214938897, 'reg_lambda': 0.06396572390801536}. Best is trial 0 with value: 0.7868217054263565.
# [I 2025-11-03 19:47:12,571] Trial 2 finished with value: 0.7728155339805826 and parameters: {'n_estimators': 383, 'max_depth': 7, 'learning_rate': 0.1195683098559626, 'subsample': 0.9998546196894922, 'colsample_bytree': 0.6801390765022889, 'reg_alpha': 0.6331785700468525, 'reg_lambda': 0.7576620104131397}. Best is trial 0 with value: 0.7868217054263565.
# [I 2025-11-03 19:47:13,309] Trial 3 finished with value: 0.7805825242718447 and parameters: {'n_estimators': 958, 'max_depth': 6, 'learning_rate': 0.10422174963149952, 'subsample': 0.7909568243014635, 'colsample_bytree': 0.7366972593185952, 'reg_alpha': 0.3368130194700507, 'reg_lambda': 0.02472458048099957}. Best is trial 0 with value: 0.7868217054263565.
# [I 2025-11-03 19:47:14,070] Trial 4 finished with value: 0.7868217054263565 and parameters: {'n_estimators': 884, 'max_depth': 6, 'learning_rate': 0.024619431010280975, 'subsample': 0.870230305722028, 'colsample_bytree': 0.8565587585305527, 'reg_alpha': 0.7397867832745831, 'reg_lambda': 0.39793267831860546}. Best is trial 0 with value: 0.7868217054263565.
# [I 2025-11-03 19:47:14,722] Trial 5 finished with value: 0.793036750483559 and parameters: {'n_estimators': 503, 'max_depth': 10, 'learning_rate': 0.023608994549633538, 'subsample': 0.8310472918510347, 'colsample_bytree': 0.8160417253670931, 'reg_alpha': 0.8445144457218497, 'reg_lambda': 0.9372491909578018}. Best is trial 5 with value: 0.793036750483559.
# [I 2025-11-03 19:47:15,463] Trial 6 finished with value: 0.7764705882352941 and parameters: {'n_estimators': 685, 'max_depth': 10, 'learning_rate': 0.03803347348489716, 'subsample': 0.6956424098985408, 'colsample_bytree': 0.7065921606754726, 'reg_alpha': 0.2896099790135578, 'reg_lambda': 0.461536565211323}. Best is trial 5 with value: 0.793036750483559.
# [I 2025-11-03 19:47:15,945] Trial 7 finished with value: 0.7816091954022989 and parameters: {'n_estimators': 679, 'max_depth': 6, 'learning_rate': 0.14969222928030324, 'subsample': 0.9412396037922568, 'colsample_bytree': 0.767019953592208, 'reg_alpha': 0.41963006642260214, 'reg_lambda': 0.6483260272318028}. Best is trial 5 with value: 0.793036750483559.
# [I 2025-11-03 19:47:16,441] Trial 8 finished with value: 0.7788649706457925 and parameters: {'n_estimators': 874, 'max_depth': 4, 'learning_rate': 0.015687008356895377, 'subsample': 0.9093269756169903, 'colsample_bytree': 0.7024723290276856, 'reg_alpha': 0.9189086125035738, 'reg_lambda': 0.9982772092622727}. Best is trial 5 with value: 0.793036750483559.
# [I 2025-11-03 19:47:16,725] Trial 9 finished with value: 0.7907869481765835 and parameters: {'n_estimators': 222, 'max_depth': 9, 'learning_rate': 0.026926747744841044, 'subsample': 0.7799647816754909, 'colsample_bytree': 0.8023980520482124, 'reg_alpha': 0.9735057929743357, 'reg_lambda': 0.3666746464286956}. Best is trial 5 with value: 0.793036750483559.
# [I 2025-11-03 19:47:17,232] Trial 10 finished with value: 0.7861271676300579 and parameters: {'n_estimators': 447, 'max_depth': 8, 'learning_rate': 0.010025995891051357, 'subsample': 0.6178629169597138, 'colsample_bytree': 0.6040061231792602, 'reg_alpha': 0.041944733300198656, 'reg_lambda': 0.9993128042441629}. Best is trial 5 with value: 0.793036750483559.
# [I 2025-11-03 19:47:17,437] Trial 11 finished with value: 0.7884615384615384 and parameters: {'n_estimators': 120, 'max_depth': 10, 'learning_rate': 0.059598389219114034, 'subsample': 0.7765755227472766, 'colsample_bytree': 0.9762823149127817, 'reg_alpha': 0.9999748067163676, 'reg_lambda': 0.263188255201847}. Best is trial 5 with value: 0.793036750483559.
# [I 2025-11-03 19:47:17,810] Trial 12 finished with value: 0.7876447876447876 and parameters: {'n_estimators': 292, 'max_depth': 9, 'learning_rate': 0.023096949258360068, 'subsample': 0.7279862634971391, 'colsample_bytree': 0.8145479510857592, 'reg_alpha': 0.7453520157621296, 'reg_lambda': 0.28566981949505155}. Best is trial 5 with value: 0.793036750483559.
# [I 2025-11-03 19:47:18,368] Trial 13 finished with value: 0.7898832684824902 and parameters: {'n_estimators': 535, 'max_depth': 8, 'learning_rate': 0.06029224393744378, 'subsample': 0.8376644738687573, 'colsample_bytree': 0.9084712170062164, 'reg_alpha': 0.8276697457292075, 'reg_lambda': 0.5975051466683348}. Best is trial 5 with value: 0.793036750483559.
# [I 2025-11-03 19:47:18,804] Trial 14 finished with value: 0.781431334622824 and parameters: {'n_estimators': 302, 'max_depth': 10, 'learning_rate': 0.016758990662489644, 'subsample': 0.7327559236985908, 'colsample_bytree': 0.7931703813430935, 'reg_alpha': 0.5975989622785318, 'reg_lambda': 0.21317495766130365}. Best is trial 5 with value: 0.793036750483559.
# [I 2025-11-03 19:47:19,491] Trial 15 finished with value: 0.7868217054263565 and parameters: {'n_estimators': 664, 'max_depth': 8, 'learning_rate': 0.040397089415316605, 'subsample': 0.8162320793180544, 'colsample_bytree': 0.8502544023491021, 'reg_alpha': 0.7856986573575643, 'reg_lambda': 0.8256685703948718}. Best is trial 5 with value: 0.793036750483559.
# [I 2025-11-03 19:47:20,028] Trial 16 finished with value: 0.7852998065764023 and parameters: {'n_estimators': 519, 'max_depth': 9, 'learning_rate': 0.02452766502370686, 'subsample': 0.6547705108390445, 'colsample_bytree': 0.9106954101816326, 'reg_alpha': 0.9745859726970644, 'reg_lambda': 0.5639277766380176}. Best is trial 5 with value: 0.793036750483559.
# [I 2025-11-03 19:47:20,143] Trial 17 finished with value: 0.7962264150943397 and parameters: {'n_estimators': 101, 'max_depth': 7, 'learning_rate': 0.010466429197724884, 'subsample': 0.7517994792724202, 'colsample_bytree': 0.6403432379467009, 'reg_alpha': 0.654880575682208, 'reg_lambda': 0.40048317634836383}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:20,556] Trial 18 finished with value: 0.7790697674418605 and parameters: {'n_estimators': 754, 'max_depth': 5, 'learning_rate': 0.010128604739758237, 'subsample': 0.8526233062721102, 'colsample_bytree': 0.6003866926160091, 'reg_alpha': 0.6319338480631581, 'reg_lambda': 0.8755706103021089}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:20,794] Trial 19 finished with value: 0.781431334622824 and parameters: {'n_estimators': 407, 'max_depth': 5, 'learning_rate': 0.015224290502475413, 'subsample': 0.7321936367254709, 'colsample_bytree': 0.6593419400921743, 'reg_alpha': 0.13227184975097817, 'reg_lambda': 0.6901550593837096}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:20,929] Trial 20 finished with value: 0.7847619047619048 and parameters: {'n_estimators': 125, 'max_depth': 7, 'learning_rate': 0.013231624728030146, 'subsample': 0.6658891492540562, 'colsample_bytree': 0.7470271572304873, 'reg_alpha': 0.5497130335902853, 'reg_lambda': 0.4994795893117371}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:21,196] Trial 21 finished with value: 0.7846153846153846 and parameters: {'n_estimators': 237, 'max_depth': 9, 'learning_rate': 0.02072986465265568, 'subsample': 0.7647383790025292, 'colsample_bytree': 0.8003057049659851, 'reg_alpha': 0.8529322177916301, 'reg_lambda': 0.3680071602131042}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:21,337] Trial 22 finished with value: 0.7839388145315488 and parameters: {'n_estimators': 102, 'max_depth': 10, 'learning_rate': 0.03155271960024314, 'subsample': 0.8061198005685865, 'colsample_bytree': 0.8230643418810395, 'reg_alpha': 0.7028094630025115, 'reg_lambda': 0.16097909908234256}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:21,547] Trial 23 finished with value: 0.7797270955165692 and parameters: {'n_estimators': 212, 'max_depth': 7, 'learning_rate': 0.04858113778545413, 'subsample': 0.758986636497319, 'colsample_bytree': 0.7682667306472108, 'reg_alpha': 0.8804545662223145, 'reg_lambda': 0.3276331851918596}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:21,818] Trial 24 finished with value: 0.77734375 and parameters: {'n_estimators': 318, 'max_depth': 8, 'learning_rate': 0.08479198163832634, 'subsample': 0.8750170800314878, 'colsample_bytree': 0.639339882840738, 'reg_alpha': 0.7030491407285171, 'reg_lambda': 0.4306341383588445}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:22,027] Trial 25 finished with value: 0.789980732177264 and parameters: {'n_estimators': 178, 'max_depth': 9, 'learning_rate': 0.0292484618490312, 'subsample': 0.8232878707038852, 'colsample_bytree': 0.8811466604014703, 'reg_alpha': 0.8003080639815753, 'reg_lambda': 0.13495025306406472}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:22,639] Trial 26 finished with value: 0.7923076923076923 and parameters: {'n_estimators': 599, 'max_depth': 10, 'learning_rate': 0.01254779570143139, 'subsample': 0.6837715085329298, 'colsample_bytree': 0.7248159964149782, 'reg_alpha': 0.9536868232973394, 'reg_lambda': 0.549235962118465}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:23,212] Trial 27 finished with value: 0.7915057915057915 and parameters: {'n_estimators': 572, 'max_depth': 10, 'learning_rate': 0.013098970644136386, 'subsample': 0.6016296104736697, 'colsample_bytree': 0.728690359533919, 'reg_alpha': 0.6630455289436173, 'reg_lambda': 0.5340741703200685}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:23,507] Trial 28 finished with value: 0.7677165354330708 and parameters: {'n_estimators': 782, 'max_depth': 3, 'learning_rate': 0.018954485651709325, 'subsample': 0.6894493448239996, 'colsample_bytree': 0.6301078746027439, 'reg_alpha': 0.9034073061066399, 'reg_lambda': 0.9156358873584406}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:23,746] Trial 29 finished with value: 0.7613412228796844 and parameters: {'n_estimators': 603, 'max_depth': 3, 'learning_rate': 0.27519253264082444, 'subsample': 0.6827240453999845, 'colsample_bytree': 0.6773180555725726, 'reg_alpha': 0.9271589148052698, 'reg_lambda': 0.7296155611347334}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:24,050] Trial 30 finished with value: 0.7775628626692457 and parameters: {'n_estimators': 495, 'max_depth': 5, 'learning_rate': 0.012502790881322244, 'subsample': 0.6491599012947253, 'colsample_bytree': 0.695961903395916, 'reg_alpha': 0.8367005482873344, 'reg_lambda': 0.6040213735036277}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:24,563] Trial 31 finished with value: 0.7891682785299806 and parameters: {'n_estimators': 482, 'max_depth': 10, 'learning_rate': 0.01235145573367196, 'subsample': 0.6112026096450675, 'colsample_bytree': 0.7157844250535812, 'reg_alpha': 0.6743461027115508, 'reg_lambda': 0.4701213030622913}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:25,183] Trial 32 finished with value: 0.7883495145631068 and parameters: {'n_estimators': 572, 'max_depth': 10, 'learning_rate': 0.0122919324032155, 'subsample': 0.7135035708474757, 'colsample_bytree': 0.7362636978581831, 'reg_alpha': 0.5064559743069053, 'reg_lambda': 0.5650035481423474}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:25,808] Trial 33 finished with value: 0.7891682785299806 and parameters: {'n_estimators': 616, 'max_depth': 10, 'learning_rate': 0.018268548624155258, 'subsample': 0.6388815242181044, 'colsample_bytree': 0.7699677904933246, 'reg_alpha': 0.5730801077764461, 'reg_lambda': 0.545939513081158}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:26,530] Trial 34 finished with value: 0.7868217054263565 and parameters: {'n_estimators': 758, 'max_depth': 9, 'learning_rate': 0.010055724861038206, 'subsample': 0.6222375965165277, 'colsample_bytree': 0.6603774537834644, 'reg_alpha': 0.4450908907508383, 'reg_lambda': 0.6645410222284098}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:26,944] Trial 35 finished with value: 0.781431334622824 and parameters: {'n_estimators': 409, 'max_depth': 8, 'learning_rate': 0.01454589047820365, 'subsample': 0.7481694858589957, 'colsample_bytree': 0.7246021504605794, 'reg_alpha': 0.6513344404598528, 'reg_lambda': 0.7398086297619761}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:27,346] Trial 36 finished with value: 0.7859922178988327 and parameters: {'n_estimators': 371, 'max_depth': 9, 'learning_rate': 0.02099763710522491, 'subsample': 0.7072159738557826, 'colsample_bytree': 0.7545769043146833, 'reg_alpha': 0.7375265049069766, 'reg_lambda': 0.8096153709268489}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:28,310] Trial 37 finished with value: 0.7844660194174757 and parameters: {'n_estimators': 989, 'max_depth': 10, 'learning_rate': 0.017288771272404985, 'subsample': 0.6026717001271724, 'colsample_bytree': 0.8373688334817381, 'reg_alpha': 0.7657616824276481, 'reg_lambda': 0.39874073712699143}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:28,968] Trial 38 finished with value: 0.77431906614786 and parameters: {'n_estimators': 818, 'max_depth': 7, 'learning_rate': 0.011972299576232717, 'subsample': 0.6692301128725073, 'colsample_bytree': 0.6806552318274526, 'reg_alpha': 0.3600330838336047, 'reg_lambda': 0.5345057551370751}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:29,434] Trial 39 finished with value: 0.7854406130268199 and parameters: {'n_estimators': 636, 'max_depth': 6, 'learning_rate': 0.034657772695775, 'subsample': 0.8936013891109014, 'colsample_bytree': 0.7831244274568974, 'reg_alpha': 0.940456315847606, 'reg_lambda': 0.92306266680914}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:29,795] Trial 40 finished with value: 0.7829457364341085 and parameters: {'n_estimators': 721, 'max_depth': 4, 'learning_rate': 0.014842124159820337, 'subsample': 0.9330461733425088, 'colsample_bytree': 0.633102425228232, 'reg_alpha': 0.217544465086301, 'reg_lambda': 0.4652573011495894}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:30,050] Trial 41 finished with value: 0.7946257197696737 and parameters: {'n_estimators': 166, 'max_depth': 10, 'learning_rate': 0.02617132903256689, 'subsample': 0.7823940736728797, 'colsample_bytree': 0.8709387548927724, 'reg_alpha': 0.9647127516253828, 'reg_lambda': 0.33317294991953117}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:30,388] Trial 42 finished with value: 0.7898832684824902 and parameters: {'n_estimators': 258, 'max_depth': 10, 'learning_rate': 0.02452316727722948, 'subsample': 0.7995957524507294, 'colsample_bytree': 0.8740319316688641, 'reg_alpha': 0.8720962882242096, 'reg_lambda': 0.32796836495997617}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:30,633] Trial 43 finished with value: 0.7869481765834933 and parameters: {'n_estimators': 176, 'max_depth': 10, 'learning_rate': 0.01924823642994514, 'subsample': 0.7880868674987651, 'colsample_bytree': 0.9355278427304501, 'reg_alpha': 0.9392277992691265, 'reg_lambda': 0.0008994583417204494}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:31,172] Trial 44 finished with value: 0.7861271676300579 and parameters: {'n_estimators': 568, 'max_depth': 9, 'learning_rate': 0.046151269849280405, 'subsample': 0.9680730808494789, 'colsample_bytree': 0.8215654300590078, 'reg_alpha': 0.9872181002673305, 'reg_lambda': 0.24787474695828235}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:31,531] Trial 45 finished with value: 0.7869481765834933 and parameters: {'n_estimators': 357, 'max_depth': 9, 'learning_rate': 0.07978559760251201, 'subsample': 0.8396478692377017, 'colsample_bytree': 0.8939969829265086, 'reg_alpha': 0.806593039032214, 'reg_lambda': 0.4119898242404398}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:32,079] Trial 46 finished with value: 0.7868217054263565 and parameters: {'n_estimators': 447, 'max_depth': 10, 'learning_rate': 0.01087363355363394, 'subsample': 0.7523987367556644, 'colsample_bytree': 0.8610354799476492, 'reg_alpha': 0.8800200835197898, 'reg_lambda': 0.31185589310635287}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:32,273] Trial 47 finished with value: 0.7861271676300579 and parameters: {'n_estimators': 139, 'max_depth': 10, 'learning_rate': 0.028017774733386208, 'subsample': 0.6361736270006011, 'colsample_bytree': 0.8389058379195432, 'reg_alpha': 0.7094808826573176, 'reg_lambda': 0.21925158468478018}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:32,926] Trial 48 finished with value: 0.7829457364341085 and parameters: {'n_estimators': 690, 'max_depth': 8, 'learning_rate': 0.014247326520513517, 'subsample': 0.7774723766869099, 'colsample_bytree': 0.9522021778150517, 'reg_alpha': 0.619610793500257, 'reg_lambda': 0.12412291869403014}. Best is trial 17 with value: 0.7962264150943397.
# [I 2025-11-03 19:47:33,817] Trial 49 finished with value: 0.783625730994152 and parameters: {'n_estimators': 854, 'max_depth': 10, 'learning_rate': 0.01644048033693239, 'subsample': 0.715984122917161, 'colsample_bytree': 0.6956754932466503, 'reg_alpha': 0.5030206946036339, 'reg_lambda': 0.6266117979879977}. Best is trial 17 with value: 0.7962264150943397.
# Best parameters: {'n_estimators': 101, 'max_depth': 7, 'learning_rate': 0.010466429197724884, 'subsample': 0.7517994792724202, 'colsample_bytree': 0.6403432379467009, 'reg_alpha': 0.654880575682208, 'reg_lambda': 0.40048317634836383}
# Best F1-score: 0.7962264150943397

# %%
print("Best xgboost parameters:", study_xgboost.best_params)
print("Best xgboost F1-score:", study_xgboost.best_value)
# Out:
# Best xgboost parameters: {'n_estimators': 101, 'max_depth': 7, 'learning_rate': 0.010466429197724884, 'subsample': 0.7517994792724202, 'colsample_bytree': 0.6403432379467009, 'reg_alpha': 0.654880575682208, 'reg_lambda': 0.40048317634836383}
# Best xgboost F1-score: 0.7962264150943397

# %% [markdown]
# ### CatBoost

# %%
def objective_optuna_catboost(trial):
    params = {
        'iterations': trial.suggest_int('iterations', 100, 1000),
        'depth': trial.suggest_int('depth', 4, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1, 10),
        'random_strength': trial.suggest_float('random_strength', 0.1, 2),
        'bagging_temperature': trial.suggest_float('bagging_temperature', 0, 1),
        'border_count': trial.suggest_int('border_count', 32, 255),
        'random_state': 42,
        'verbose': False
    }
    
    model = CatBoostClassifier(**params)
    model.fit(X_ss_train, y_ss_train)
    
    y_pred = model.predict(X_ss_test)
    f1 = f1_score(y_ss_test, y_pred)
    
    return f1

study_catboost = optuna.create_study(direction='maximize')
study_catboost.optimize(objective_optuna_catboost, n_trials=50, show_progress_bar=True)

print("Best parameters:", study_catboost.best_params)
print("Best F1-score:", study_catboost.best_value)
# Out:
# [I 2025-11-03 19:53:51,528] A new study created in memory with name: no-name-57f622c8-d2f8-43ec-a813-f95a706d93f1
#   0%|          | 0/50 [00:00<?, ?it/s]
# [I 2025-11-03 19:53:52,943] Trial 0 finished with value: 0.8 and parameters: {'iterations': 458, 'depth': 8, 'learning_rate': 0.06403048056219847, 'l2_leaf_reg': 8.95818667067491, 'random_strength': 1.3606232889452015, 'bagging_temperature': 0.26629269029161984, 'border_count': 84}. Best is trial 0 with value: 0.8.
# [I 2025-11-03 19:53:54,144] Trial 1 finished with value: 0.7689320388349514 and parameters: {'iterations': 791, 'depth': 4, 'learning_rate': 0.09249041166553533, 'l2_leaf_reg': 1.640995674491994, 'random_strength': 0.17766086786352106, 'bagging_temperature': 0.959228774990283, 'border_count': 157}. Best is trial 0 with value: 0.8.
# [I 2025-11-03 19:54:01,134] Trial 2 finished with value: 0.8062015503875969 and parameters: {'iterations': 975, 'depth': 10, 'learning_rate': 0.22156435955115417, 'l2_leaf_reg': 7.799036224811638, 'random_strength': 1.5602292862128597, 'bagging_temperature': 0.8203929005911199, 'border_count': 94}. Best is trial 2 with value: 0.8062015503875969.
# [I 2025-11-03 19:54:01,670] Trial 3 finished with value: 0.7829457364341085 and parameters: {'iterations': 214, 'depth': 7, 'learning_rate': 0.1660620129664627, 'l2_leaf_reg': 2.2872163698060204, 'random_strength': 1.326120893311502, 'bagging_temperature': 0.5779296351114732, 'border_count': 122}. Best is trial 2 with value: 0.8062015503875969.
# [I 2025-11-03 19:54:02,488] Trial 4 finished with value: 0.780114722753346 and parameters: {'iterations': 294, 'depth': 7, 'learning_rate': 0.11493434637322915, 'l2_leaf_reg': 4.63746692007863, 'random_strength': 0.6124215294143807, 'bagging_temperature': 0.1891412412198371, 'border_count': 165}. Best is trial 2 with value: 0.8062015503875969.
# [I 2025-11-03 19:54:03,567] Trial 5 finished with value: 0.7855787476280834 and parameters: {'iterations': 284, 'depth': 8, 'learning_rate': 0.0985688398063978, 'l2_leaf_reg': 5.630748035753589, 'random_strength': 1.5224554831213137, 'bagging_temperature': 0.029728895385003784, 'border_count': 165}. Best is trial 2 with value: 0.8062015503875969.
# [I 2025-11-03 19:54:04,519] Trial 6 finished with value: 0.7977315689981096 and parameters: {'iterations': 546, 'depth': 4, 'learning_rate': 0.014246006582803936, 'l2_leaf_reg': 8.55235550369651, 'random_strength': 1.2507322319128158, 'bagging_temperature': 0.10795564094179078, 'border_count': 184}. Best is trial 2 with value: 0.8062015503875969.
# [I 2025-11-03 19:54:05,478] Trial 7 finished with value: 0.7962264150943397 and parameters: {'iterations': 214, 'depth': 9, 'learning_rate': 0.016470598445563464, 'l2_leaf_reg': 4.087284841615287, 'random_strength': 1.9178197886806445, 'bagging_temperature': 0.4006346578809199, 'border_count': 105}. Best is trial 2 with value: 0.8062015503875969.
# [I 2025-11-03 19:54:08,359] Trial 8 finished with value: 0.7855787476280834 and parameters: {'iterations': 794, 'depth': 8, 'learning_rate': 0.03501792499396978, 'l2_leaf_reg': 3.8216454935831194, 'random_strength': 0.7771216515147469, 'bagging_temperature': 0.5996686360282149, 'border_count': 155}. Best is trial 2 with value: 0.8062015503875969.
# [I 2025-11-03 19:54:15,304] Trial 9 finished with value: 0.7884615384615384 and parameters: {'iterations': 452, 'depth': 10, 'learning_rate': 0.1815781538409444, 'l2_leaf_reg': 9.569159590608367, 'random_strength': 1.3716827395045554, 'bagging_temperature': 0.8537634469195957, 'border_count': 252}. Best is trial 2 with value: 0.8062015503875969.
# [I 2025-11-03 19:54:20,164] Trial 10 finished with value: 0.780952380952381 and parameters: {'iterations': 1000, 'depth': 10, 'learning_rate': 0.22124133481945502, 'l2_leaf_reg': 6.721380086326965, 'random_strength': 1.9695376747262099, 'bagging_temperature': 0.7482026797189005, 'border_count': 41}. Best is trial 2 with value: 0.8062015503875969.
# [I 2025-11-03 19:54:21,579] Trial 11 finished with value: 0.793168880455408 and parameters: {'iterations': 739, 'depth': 6, 'learning_rate': 0.03437230929019098, 'l2_leaf_reg': 7.683741042913489, 'random_strength': 1.6622696647209043, 'bagging_temperature': 0.3484297679325285, 'border_count': 77}. Best is trial 2 with value: 0.8062015503875969.
# [I 2025-11-03 19:54:25,015] Trial 12 finished with value: 0.7969348659003831 and parameters: {'iterations': 971, 'depth': 9, 'learning_rate': 0.04577826825227777, 'l2_leaf_reg': 9.903422072129203, 'random_strength': 0.995408703644562, 'bagging_temperature': 0.2749208370572894, 'border_count': 68}. Best is trial 2 with value: 0.8062015503875969.
# [I 2025-11-03 19:54:25,934] Trial 13 finished with value: 0.7816091954022989 and parameters: {'iterations': 464, 'depth': 6, 'learning_rate': 0.2987572158309818, 'l2_leaf_reg': 7.582985861952528, 'random_strength': 1.754214066149868, 'bagging_temperature': 0.7098560961905276, 'border_count': 96}. Best is trial 2 with value: 0.8062015503875969.
# [I 2025-11-03 19:54:27,993] Trial 14 finished with value: 0.7946257197696737 and parameters: {'iterations': 675, 'depth': 9, 'learning_rate': 0.06285807784168748, 'l2_leaf_reg': 8.757402005260438, 'random_strength': 1.0027552837190405, 'bagging_temperature': 0.44960981442822595, 'border_count': 45}. Best is trial 2 with value: 0.8062015503875969.
# [I 2025-11-03 19:54:28,845] Trial 15 finished with value: 0.8075471698113208 and parameters: {'iterations': 102, 'depth': 10, 'learning_rate': 0.01959986924412001, 'l2_leaf_reg': 6.4854749331162616, 'random_strength': 1.5887048422832135, 'bagging_temperature': 0.9767622815950558, 'border_count': 122}. Best is trial 15 with value: 0.8075471698113208.
# [I 2025-11-03 19:54:29,769] Trial 16 finished with value: 0.8128544423440454 and parameters: {'iterations': 104, 'depth': 10, 'learning_rate': 0.022687965211251798, 'l2_leaf_reg': 6.156684724229312, 'random_strength': 1.651257412932696, 'bagging_temperature': 0.998739665895921, 'border_count': 128}. Best is trial 16 with value: 0.8128544423440454.
# [I 2025-11-03 19:54:31,641] Trial 17 finished with value: 0.8075471698113208 and parameters: {'iterations': 157, 'depth': 10, 'learning_rate': 0.010140514407845962, 'l2_leaf_reg': 5.993227460365789, 'random_strength': 1.7815526580735424, 'bagging_temperature': 0.9944199582166905, 'border_count': 198}. Best is trial 16 with value: 0.8128544423440454.
# [I 2025-11-03 19:54:32,081] Trial 18 finished with value: 0.8015267175572519 and parameters: {'iterations': 106, 'depth': 9, 'learning_rate': 0.021862157999482656, 'l2_leaf_reg': 6.483386486716834, 'random_strength': 1.175528279849053, 'bagging_temperature': 0.9056575910627186, 'border_count': 123}. Best is trial 16 with value: 0.8128544423440454.
# [I 2025-11-03 19:54:32,818] Trial 19 finished with value: 0.7946768060836502 and parameters: {'iterations': 356, 'depth': 5, 'learning_rate': 0.026263383809692654, 'l2_leaf_reg': 4.9797777040550555, 'random_strength': 1.5513597262599197, 'bagging_temperature': 0.6992375693182172, 'border_count': 234}. Best is trial 16 with value: 0.8128544423440454.
# [I 2025-11-03 19:54:33,096] Trial 20 finished with value: 0.8060836501901141 and parameters: {'iterations': 109, 'depth': 8, 'learning_rate': 0.01949470127872146, 'l2_leaf_reg': 3.3761631709021813, 'random_strength': 0.17636686554876602, 'bagging_temperature': 0.8047598199815144, 'border_count': 117}. Best is trial 16 with value: 0.8128544423440454.
# [I 2025-11-03 19:54:35,214] Trial 21 finished with value: 0.8090737240075614 and parameters: {'iterations': 179, 'depth': 10, 'learning_rate': 0.010248863588693044, 'l2_leaf_reg': 6.027415725738585, 'random_strength': 1.803291357708257, 'bagging_temperature': 0.9737716776572886, 'border_count': 198}. Best is trial 16 with value: 0.8128544423440454.
# [I 2025-11-03 19:54:37,762] Trial 22 finished with value: 0.8045540796963947 and parameters: {'iterations': 204, 'depth': 10, 'learning_rate': 0.010904198505124953, 'l2_leaf_reg': 6.823428362710386, 'random_strength': 1.926055670138359, 'bagging_temperature': 0.9116923671827462, 'border_count': 197}. Best is trial 16 with value: 0.8128544423440454.
# [I 2025-11-03 19:54:39,465] Trial 23 finished with value: 0.793168880455408 and parameters: {'iterations': 329, 'depth': 9, 'learning_rate': 0.014296895939215192, 'l2_leaf_reg': 4.997046691651557, 'random_strength': 1.7796647941160157, 'bagging_temperature': 0.9986719890779144, 'border_count': 138}. Best is trial 16 with value: 0.8128544423440454.
# [I 2025-11-03 19:54:41,623] Trial 24 finished with value: 0.8052930056710775 and parameters: {'iterations': 172, 'depth': 10, 'learning_rate': 0.026354737851223744, 'l2_leaf_reg': 6.03655147021418, 'random_strength': 1.6314595355737158, 'bagging_temperature': 0.9032395235362635, 'border_count': 218}. Best is trial 16 with value: 0.8128544423440454.
# [I 2025-11-03 19:54:43,010] Trial 25 finished with value: 0.7931034482758621 and parameters: {'iterations': 262, 'depth': 9, 'learning_rate': 0.013526930633000402, 'l2_leaf_reg': 7.174620437590631, 'random_strength': 1.4534796227857025, 'bagging_temperature': 0.5989086442877191, 'border_count': 141}. Best is trial 16 with value: 0.8128544423440454.
# [I 2025-11-03 19:54:44,250] Trial 26 finished with value: 0.8134328358208955 and parameters: {'iterations': 108, 'depth': 10, 'learning_rate': 0.019573748732898265, 'l2_leaf_reg': 5.473367185401033, 'random_strength': 1.1506042155847689, 'bagging_temperature': 0.780195513041266, 'border_count': 181}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:54:46,550] Trial 27 finished with value: 0.7923809523809524 and parameters: {'iterations': 366, 'depth': 9, 'learning_rate': 0.035165050007301114, 'l2_leaf_reg': 3.1821816071054574, 'random_strength': 0.7363460770395742, 'bagging_temperature': 0.7493833999018069, 'border_count': 183}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:54:51,835] Trial 28 finished with value: 0.8037735849056604 and parameters: {'iterations': 403, 'depth': 10, 'learning_rate': 0.01223433825042057, 'l2_leaf_reg': 4.458200132890695, 'random_strength': 1.1097069066052851, 'bagging_temperature': 0.8563297943874324, 'border_count': 216}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:54:52,822] Trial 29 finished with value: 0.803030303030303 and parameters: {'iterations': 236, 'depth': 8, 'learning_rate': 0.04661549581690396, 'l2_leaf_reg': 5.429179709892142, 'random_strength': 0.3912704201775553, 'bagging_temperature': 0.636134796708119, 'border_count': 183}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:54:53,361] Trial 30 finished with value: 0.8022813688212928 and parameters: {'iterations': 148, 'depth': 8, 'learning_rate': 0.025559394781825603, 'l2_leaf_reg': 5.560647005186442, 'random_strength': 1.390643501898718, 'bagging_temperature': 0.5028304485340263, 'border_count': 217}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:54:54,344] Trial 31 finished with value: 0.803030303030303 and parameters: {'iterations': 107, 'depth': 10, 'learning_rate': 0.017698748739269726, 'l2_leaf_reg': 6.202992926369414, 'random_strength': 1.7007196025804925, 'bagging_temperature': 0.9397819092284647, 'border_count': 133}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:54:55,921] Trial 32 finished with value: 0.8106060606060606 and parameters: {'iterations': 163, 'depth': 10, 'learning_rate': 0.023828251376804135, 'l2_leaf_reg': 7.034367719731472, 'random_strength': 1.8409212182793016, 'bagging_temperature': 0.9642594685122075, 'border_count': 150}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:54:57,586] Trial 33 finished with value: 0.8128544423440454 and parameters: {'iterations': 168, 'depth': 10, 'learning_rate': 0.0290602440689298, 'l2_leaf_reg': 8.169607088125526, 'random_strength': 1.8121481832209376, 'bagging_temperature': 0.8044308697918291, 'border_count': 154}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:54:59,117] Trial 34 finished with value: 0.7977315689981096 and parameters: {'iterations': 257, 'depth': 9, 'learning_rate': 0.04297301163990708, 'l2_leaf_reg': 8.152183725155512, 'random_strength': 1.9979745853003499, 'bagging_temperature': 0.8107971096802986, 'border_count': 157}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:02,770] Trial 35 finished with value: 0.7862595419847328 and parameters: {'iterations': 314, 'depth': 10, 'learning_rate': 0.029142783198864354, 'l2_leaf_reg': 7.164141321717304, 'random_strength': 1.8679750273419606, 'bagging_temperature': 0.8672876786973874, 'border_count': 168}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:03,604] Trial 36 finished with value: 0.7839388145315488 and parameters: {'iterations': 180, 'depth': 9, 'learning_rate': 0.07596659589003843, 'l2_leaf_reg': 1.283935768542828, 'random_strength': 0.8848389353859892, 'bagging_temperature': 0.7832025188345884, 'border_count': 153}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:05,231] Trial 37 finished with value: 0.7748091603053435 and parameters: {'iterations': 559, 'depth': 7, 'learning_rate': 0.023332962619575515, 'l2_leaf_reg': 9.270057285258451, 'random_strength': 0.44040480103153246, 'bagging_temperature': 0.6568608656954372, 'border_count': 177}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:07,278] Trial 38 finished with value: 0.8015122873345936 and parameters: {'iterations': 234, 'depth': 10, 'learning_rate': 0.0162399882529315, 'l2_leaf_reg': 7.923522598132095, 'random_strength': 1.2744024801739693, 'bagging_temperature': 0.9199238365046677, 'border_count': 105}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:07,915] Trial 39 finished with value: 0.7984790874524715 and parameters: {'iterations': 142, 'depth': 9, 'learning_rate': 0.03134325560116663, 'l2_leaf_reg': 7.24826620040219, 'random_strength': 1.8644196955636072, 'bagging_temperature': 0.5194019161372476, 'border_count': 146}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:08,748] Trial 40 finished with value: 0.7885714285714286 and parameters: {'iterations': 282, 'depth': 7, 'learning_rate': 0.04135649135435009, 'l2_leaf_reg': 8.392799817615163, 'random_strength': 1.486151319677929, 'bagging_temperature': 0.8565002853907373, 'border_count': 166}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:11,077] Trial 41 finished with value: 0.8053435114503816 and parameters: {'iterations': 195, 'depth': 10, 'learning_rate': 0.02027985054758019, 'l2_leaf_reg': 5.106117909144098, 'random_strength': 1.8174110406978836, 'bagging_temperature': 0.9600969352030442, 'border_count': 199}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:12,916] Trial 42 finished with value: 0.8068181818181818 and parameters: {'iterations': 149, 'depth': 10, 'learning_rate': 0.015982959395747582, 'l2_leaf_reg': 5.733481931657498, 'random_strength': 1.6783790175829942, 'bagging_temperature': 0.9473711017606873, 'border_count': 205}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:15,046] Trial 43 finished with value: 0.8105065666041276 and parameters: {'iterations': 193, 'depth': 10, 'learning_rate': 0.01315969266387908, 'l2_leaf_reg': 6.811396452556878, 'random_strength': 1.735699706926541, 'bagging_temperature': 0.7666236003165481, 'border_count': 169}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:17,686] Trial 44 finished with value: 0.8037735849056604 and parameters: {'iterations': 217, 'depth': 10, 'learning_rate': 0.012396893931382368, 'l2_leaf_reg': 7.445083069830974, 'random_strength': 1.4271084249712531, 'bagging_temperature': 0.7677615501237851, 'border_count': 173}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:17,868] Trial 45 finished with value: 0.8097928436911488 and parameters: {'iterations': 145, 'depth': 4, 'learning_rate': 0.022972327613841236, 'l2_leaf_reg': 6.901661271838265, 'random_strength': 1.57045155847403, 'bagging_temperature': 0.6984485348520977, 'border_count': 130}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:19,449] Trial 46 finished with value: 0.7969924812030075 and parameters: {'iterations': 285, 'depth': 9, 'learning_rate': 0.01785736246656418, 'l2_leaf_reg': 8.925155115888453, 'random_strength': 1.6868654528989047, 'bagging_temperature': 0.561005141812698, 'border_count': 153}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:27,493] Trial 47 finished with value: 0.7984644913627639 and parameters: {'iterations': 912, 'depth': 10, 'learning_rate': 0.054300312425526326, 'l2_leaf_reg': 7.858742025379516, 'random_strength': 1.292671373564361, 'bagging_temperature': 0.8708293449252756, 'border_count': 114}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:28,691] Trial 48 finished with value: 0.7777777777777778 and parameters: {'iterations': 591, 'depth': 5, 'learning_rate': 0.1245666954323937, 'l2_leaf_reg': 6.499311117696785, 'random_strength': 1.8965707766305715, 'bagging_temperature': 0.8144388295654916, 'border_count': 146}. Best is trial 26 with value: 0.8134328358208955.
# [I 2025-11-03 19:55:31,266] Trial 49 finished with value: 0.7977099236641222 and parameters: {'iterations': 432, 'depth': 9, 'learning_rate': 0.031210850418855022, 'l2_leaf_reg': 4.5358184168945925, 'random_strength': 1.7222289596397948, 'bagging_temperature': 0.7223155882304684, 'border_count': 162}. Best is trial 26 with value: 0.8134328358208955.
# Best parameters: {'iterations': 108, 'depth': 10, 'learning_rate': 0.019573748732898265, 'l2_leaf_reg': 5.473367185401033, 'random_strength': 1.1506042155847689, 'bagging_temperature': 0.780195513041266, 'border_count': 181}
# Best F1-score: 0.8134328358208955

# %%
print("Best catboost parameters:", study_catboost.best_params)
print("Best catboost F1-score:", study_catboost.best_value)
# Out:
# Best catboost parameters: {'iterations': 108, 'depth': 10, 'learning_rate': 0.019573748732898265, 'l2_leaf_reg': 5.473367185401033, 'random_strength': 1.1506042155847689, 'bagging_temperature': 0.780195513041266, 'border_count': 181}
# Best catboost F1-score: 0.8134328358208955

# %% [raw]
# По итогу выбираем Random Forest, т.к он лучше выдает f1-score

# %% [markdown]
# ## Обучение моделей, выбор одной лучшей и версионирование результатов (ML Flow)

# %%
import os
os.environ['USER'] = 'Dima Golik'

# %%
mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment("CS2_Prediction_test")
# Out:
# 2025/11/03 23:31:56 INFO mlflow.tracking.fluent: Experiment with name 'CS2_Prediction_test' does not exist. Creating a new experiment.
# <Experiment: artifact_location='file:///C:/Desktop/Desktop/ML_Flow_Server/artefacts/207445062717580949', creation_time=1762201916097, experiment_id='207445062717580949', last_update_time=1762201916097, lifecycle_stage='active', name='CS2_Prediction_test', tags={}>

# %%
def experiment(run_name, model_class, params, train_features, train_target, test_features, test_target):
    model = None
    with mlflow.start_run(run_name=run_name):
        # Логируем параметры модели
        for name_param, param in params.items():
            mlflow.log_param(name_param, param)
        # Обучение модели
        model = model_class(**params)
        model.fit(train_features, train_target)
        # Предсказание 
        pred = model.predict(test_features)
        # Получаем метрики
        accuracy = accuracy_score(test_target, pred)
        conf_matrix = confusion_matrix(test_target, pred)
        recall = recall_score(test_target, pred)
        precision = precision_score(test_target, pred)
        # Логируем метрики
        mlflow.log_metric("accuracy", accuracy)
        mlflow.log_metric("recall", recall)
        mlflow.log_metric("precision", precision)
        mlflow.log_metric("tn", conf_matrix[0][0])
        mlflow.log_metric("fp", conf_matrix[0][1])
        mlflow.log_metric("fn", conf_matrix[1][0])
        mlflow.log_metric("tp", conf_matrix[1][1])
        # Сохранение модели в MLflow
        mlflow.sklearn.log_model(model, "model")
    mlflow.end_run()
    return model

# %%
def check_thresholds(run_name, model, test_features, test_target, necessary_precision, description):
    with mlflow.start_run(run_name=run_name):
        y_scores = model.predict_proba(test_features)[:, 1]  # Берем вероятности для класса 1
        #  Считаем precision и recall для всех возможных порогов
        precisions, recalls, thresholds = precision_recall_curve(test_target, y_scores)
        # Находим ПЕРВЫЙ порог, где precision превышает нашу цель
        index = np.argmax(precisions > necessary_precision)
        target_threshold = thresholds[index]
        # Логируем все результаты в ML Flow
        for name_param, param in model.get_params().items():
            mlflow.log_param(name_param, param)
        mlflow.set_tag("model name", model.__class__.__name__)
        mlflow.set_tag("description", description)

        mlflow.log_metric("threshold", target_threshold)
        mlflow.log_metric("New precision", precisions[index])
        mlflow.log_metric("New recall", recalls[index])
        
        mlflow.sklearn.log_model(model, "model")
        
        print("=" * 50)
        print(f"Модель: {model.__class__.__name__}")
        print(f"ЦЕЛЕВОЙ Precision: > {target_precision}")
        print(f"НАЙДЕННЫЙ ПОРОГ: {target_threshold:.3f}")
        print(f"Precision при этом пороге: {precisions[index]:.3f}")
        print(f"Recall при этом пороге: {recalls[index]:.3f}")
        print("=" * 50)
    mlflow.end_run()
    return target_threshold

# %% [markdown]
# ### Logistic regression

# %%
lr_params = {'C': 0.007294894989290226, 'penalty': 'l1', 'solver': 'saga', 'class_weight': None, 'random_state': 42}

# %%
run_lr = 'LogisticRegression_run'

# %%
description1 = "Находим порог при котором у нас precision будет > 0.9"

# %%
lr_model = experiment(
    run_name=run_lr, 
    model_class=LogisticRegression, 
    params=lr_params, 
    train_features=X_ss_train,
    train_target=y_ss_train,
    test_features=X_ss_test,
    test_target=y_ss_test
)
# Out:
# 2025/11/04 00:54:48 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/04 00:54:53 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run LogisticRegression_run at: http://localhost:5000/#/experiments/207445062717580949/runs/8ba9959e24bb4f7680a121ef121b49fc
# 🧪 View experiment at: http://localhost:5000/#/experiments/207445062717580949

# %%
lr_model.get_params()
# Out:
# {'C': 0.007294894989290226,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'deprecated',
#  'n_jobs': None,
#  'penalty': 'l1',
#  'random_state': 42,
#  'solver': 'saga',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
run_lr_thrsld = 'LogisticRegression_thresholds_run'

# %%
threshold = check_thresholds(
    run_name=run_lr_thrsld,
    model=lr_model,
    test_features=X_ss_test,
    test_target=y_ss_test,
    necessary_precision=0.9,
    description=description1
)
# Out:
# 2025/11/04 00:55:29 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/04 00:55:35 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# ==================================================
# Модель: LogisticRegression
# ЦЕЛЕВОЙ Precision: > 0.9
# НАЙДЕННЫЙ ПОРОГ: 0.598
# Precision при этом пороге: 0.901
# Recall при этом пороге: 0.502
# ==================================================
# 🏃 View run LogisticRegression_thresholds_run at: http://localhost:5000/#/experiments/207445062717580949/runs/619c1cfd962d42e095ae27d4deca6ef0
# 🧪 View experiment at: http://localhost:5000/#/experiments/207445062717580949

# %%
threshold = check_thresholds(
    run_name=run_lr_thrsld,
    model=lr_model,
    test_features=X_ss_test,
    test_target=y_ss_test,
    necessary_precision=0.87,
    description=description1
)
# Out:
# 2025/11/04 01:19:35 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/04 01:19:40 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# ==================================================
# Модель: LogisticRegression
# ЦЕЛЕВОЙ Precision: > 0.9
# НАЙДЕННЫЙ ПОРОГ: 0.572
# Precision при этом пороге: 0.871
# Recall при этом пороге: 0.608
# ==================================================
# 🏃 View run LogisticRegression_thresholds_run at: http://localhost:5000/#/experiments/207445062717580949/runs/ad96576879c047d986dbbda7c72cb69b
# 🧪 View experiment at: http://localhost:5000/#/experiments/207445062717580949

# %% [markdown]
# ### RandomForest

# %%
rf_params = {'random_state': 42, 'n_estimators': 769, 'max_depth': 5, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_leaf_nodes': 842, 'min_impurity_decrease': 0.011588676266373742, 'bootstrap': True, 'criterion': 'gini'}

# %%
description_rf = "Ищем порог для RandomForest при котором precision > 0.9"

# %%
run_rf = 'RandomForest_run'

# %%
rf_model = experiment(
    run_name=run_rf, 
    model_class=RandomForestClassifier, 
    params=rf_params, 
    train_features=X_ss_train,
    train_target=y_ss_train,
    test_features=X_ss_test,
    test_target=y_ss_test
)
# Out:
# 2025/11/04 00:56:01 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/04 00:56:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 🏃 View run RandomForest_run at: http://localhost:5000/#/experiments/207445062717580949/runs/406bc15ea11741708f9cb82afb08557f
# 🧪 View experiment at: http://localhost:5000/#/experiments/207445062717580949

# %%
run_rf_thrsld = 'RandomForest_threshold_run'

# %%
rf_threshold = check_thresholds(
    run_name=run_rf_thrsld,
    model=rf_model,
    test_features=X_ss_test,
    test_target=y_ss_test,
    necessary_precision=0.9,
    description=description_rf
)
# Out:
# 2025/11/04 00:56:24 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 2025/11/04 00:56:29 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# ==================================================
# Модель: RandomForestClassifier
# ЦЕЛЕВОЙ Precision: > 0.9
# НАЙДЕННЫЙ ПОРОГ: 0.706
# Precision при этом пороге: 0.904
# Recall при этом пороге: 0.443
# ==================================================
# 🏃 View run RandomForest_threshold_run at: http://localhost:5000/#/experiments/207445062717580949/runs/acd20ada989d4ea59fbe1bcb14a624ba
# 🧪 View experiment at: http://localhost:5000/#/experiments/207445062717580949

# %% [markdown]
# ### Сравнение

# %% [raw]
# И у логистической регрессии и случайного леса мы получили precision больше 0.9 (как мы и хотели). Но у логитической регрессии при этом recall = 0.502, а у слуайного леса - 0.443. Тут случайный лес проиграл.
# Поэтому при построении системы в другой ide мы будем использовать логистическую регрессию
